# %%
import numpy as np
import pandas as pd

# %%
from pytrends.request import TrendReq

# %%
pytrend = TrendReq()

# %%
pytrend.build_payload(kw_list=['vodafone'])

# %%
# Interest by Region
df = pytrend.interest_by_region()
df.head(10)
# Out:
#                    vodafone
# geoName
# Afghanistan               0
# Albania                  72
# Algeria                   0
# American Samoa            0
# Andorra                   0
# Angola                    0
# Anguilla                  0
# Antarctica                0
# Antigua & Barbuda         0
# Argentina                 0

# %%
df.loc[df.index.isin(['India'])]
# Out:
#          vodafone
# geoName
# India          31

# %%
df = pytrend.trending_searches(pn='india')
df.head()
# Out:
#                            0
# 0                    Threads
# 1    Scotland vs Netherlands
# 2            Realme Narzo 60
# 3  Hong Kong singer Coco Lee
# 4                   MS Dhoni

# %%
# Get Google Top Charts
df = pytrend.top_charts(2022, hl='en-US', tz=300, geo='GLOBAL')
df.head()
# Out:
#               title exploreQuery
# 0            Wordle
# 1  India vs England
# 2           Ukraine
# 3   Queen Elizabeth
# 4         Ind vs SA

# %%
pytrend.build_payload(kw_list=['Vodafone'])

# %%
related_queries = pytrend.related_queries()

# %%
related_queries['Vodafone']['top']
# Out:
#                             query  value
# 0                 vodafone number    100
# 1               vodafone internet     94
# 2               vodafone recharge     93
# 3                   vodafone idea     84
# 4                vodafone müşteri     71
# 5                     my vodafone     69
# 6     vodafone müşteri hizmetleri     60
# 7            vodafone share price     57
# 8          vodafone customer care     55
# 9                  vodafone login     51
# 10                vodafone iphone     51
# 11               vodafone störung     51
# 12                    vodafone tv     49
# 13                vodafone online     47
# 14            vodafone idea share     45
# 15      vodafone idea share price     41
# 16                 vodafone plans     36
# 17                    vodafone uk     36
# 18                        telekom     35
# 19               vodafone prepaid     35
# 20  vodafone customer care number     33
# 21                  vodafone bill     32
# ...

# %%
related_topic = pytrend.related_topics()
related_topic['Vodafone']['top']
# Out:
#     value formattedValue  hasData  \
# 0      88             88     True
# 1      88             88     True
# 2      87             87     True
# 3      82             82     True
# 4      81             81     True
# 5      80             80     True
# 6      79             79     True
# 7      78             78     True
# 8      74             74     True
# 9      74             74     True
# 10     72             72     True
# 11     69             69     True
# 12     69             69     True
# 13     66             66     True
# 14     66             66     True
# 15     65             65     True
# 16     64             64     True
# 17     58             58     True
# 18     51             51     True
# 19     46             46     True
#
#                                               link      topic_mid  \
# 0   /trends/explore?q=/g/11kw4jfq8x&date=today+5-y  /g/11kw4jfq8x
# 1       /trends/explore?q=/m/0985z0&date=today+5-y      /m/0985z0
# ...

# %%
pytrend.interest_over_time().plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list=['Vodafone', 'Deutsche Telekom', 'MTN', 'Telefonica']

#search interest per region
#run model for keywords (can also be competitors)
pytrend.build_payload(kw_list, timeframe='today 1-m', geo='DE')

# Interest by Region
regiondf = pytrend.interest_by_region()
#looking at rows where all values are not equal to 0
regiondf = regiondf[(regiondf != 0).all(1)]

#drop all rows that have null values in all columns
regiondf.dropna(how='all',axis=0, inplace=True)

#visualise
regiondf.plot(figsize=(20, 12), y=kw_list, kind ='bar')
# Out:
# <Axes: xlabel='geoName'>
